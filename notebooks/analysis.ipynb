# %%
from datasets import load_from_disk

# MELD
meld_ds = load_from_disk("data/processed/meld")
print(meld_ds)

# UltraFeedback SFT
ultra_sft_ds = load_from_disk("data/processed/ultrafeedback")
print(ultra_sft_ds)

# UltraFeedback preferences
ultra_prefs_ds = load_from_disk("data/processed/ultrafeedback_prefs")
print(ultra_prefs_ds)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from datasets import load_from_disk
#       3 # MELD
# ----> 4 meld_ds = load_from_disk("data/processed/meld")
#       5 print(meld_ds)
#       7 # UltraFeedback SFT
#
# File /opt/miniconda/envs/agentic/lib/python3.11/site-packages/datasets/load.py:1566, in load_from_disk(dataset_path, keep_in_memory, storage_options)
#    1564 fs, *_ = url_to_fs(dataset_path, **(storage_options or {}))
#    1565 if not fs.exists(dataset_path):
# -> 1566     raise FileNotFoundError(f"Directory {dataset_path} not found")
#    1567 if fs.isfile(posixpath.join(dataset_path, config.DATASET_INFO_FILENAME)) and fs.isfile(
#    1568     posixpath.join(dataset_path, config.DATASET_STATE_JSON_FILENAME)
#    1569 ):
# ...
